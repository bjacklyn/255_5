# %%
# !pip install uv
# !uv pip install apache-beam --system
# Out:
# Collecting uv
#   Downloading uv-0.4.16-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading uv-0.4.16-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 25.2 MB/s eta 0:00:00
# Installing collected packages: uv
# Successfully installed uv-0.4.16
# Resolved 44 packages in 3.18s
# Building crcmod==1.7
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠙ Preparing packages... (0/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠙ Preparing packages... (0/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠙ Preparing packages... (0/16)
# orjson     ------------------------------     0 B/138.57 KiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠙ Preparing packages... (0/16)
# orjson     ------------------------------ 2.69 KiB/138.57 KiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠙ Preparing packages... (0/16)
# orjson     ------------------------------ 2.69 KiB/138.57 KiB
# redis      ------------------------------     0 B/249.62 KiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠙ Preparing packages... (0/16)
# orjson     ------------------------------ 2.69 KiB/138.57 KiB
# redis      ------------------------------ 8.00 KiB/249.62 KiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠙ Preparing packages... (0/16)
# orjson     ------------------------------ 2.69 KiB/138.57 KiB
# redis      ------------------------------ 8.00 KiB/249.62 KiB
# zstandard  ------------------------------ 14.94 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠙ Preparing packages... (0/16)
# orjson     ------------------------------ 2.69 KiB/138.57 KiB
# redis      ------------------------------ 8.00 KiB/249.62 KiB
# zstandard  ------------------------------ 14.94 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠙ Preparing packages... (0/16)
# orjson     ------------------------------ 2.69 KiB/138.57 KiB
# redis      ------------------------------ 8.00 KiB/249.62 KiB
# pymongo    ------------------------------     0 B/1.34 MiB
# zstandard  ------------------------------ 14.94 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠙ Preparing packages... (0/16)
# orjson     ------------------------------ 2.69 KiB/138.57 KiB
# redis      ------------------------------ 8.00 KiB/249.62 KiB
# js2py      ------------------------------     0 B/1008.80 KiB
# pymongo    ------------------------------     0 B/1.34 MiB
# zstandard  ------------------------------ 14.94 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠙ Preparing packages... (0/16)
# orjson     ------------------------------ 2.69 KiB/138.57 KiB
# redis      ------------------------------ 8.00 KiB/249.62 KiB
# js2py      ------------------------------ 8.00 KiB/1008.80 KiB
# pymongo    ------------------------------     0 B/1.34 MiB
# zstandard  ------------------------------ 14.94 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠙ Preparing packages... (0/16)
# orjson     ------------------------------ 2.69 KiB/138.57 KiB
# redis      ------------------------------ 8.00 KiB/249.62 KiB
# js2py      ------------------------------ 8.00 KiB/1008.80 KiB
# pymongo    ------------------------------     0 B/1.34 MiB
# fastavro   ------------------------------     0 B/2.93 MiB
# zstandard  ------------------------------ 14.94 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠙ Preparing packages... (0/16)
# orjson     ------------------------------ 2.69 KiB/138.57 KiB
# redis      ------------------------------ 8.00 KiB/249.62 KiB
# js2py      ------------------------------ 8.00 KiB/1008.80 KiB
# pymongo    ------------------------------     0 B/1.34 MiB
# fastavro   ------------------------------ 16.00 KiB/2.93 MiB
# zstandard  ------------------------------ 14.94 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠙ Preparing packages... (0/16)
# orjson     ------------------------------ 10.77 KiB/138.57 KiB
# redis      ------------------------------ 16.00 KiB/249.62 KiB
# js2py      ------------------------------ 8.00 KiB/1008.80 KiB
# pymongo    ------------------------------     0 B/1.34 MiB
# fastavro   ------------------------------ 16.00 KiB/2.93 MiB
# zstandard  ------------------------------ 14.94 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠙ Preparing packages... (0/16)
# objsize    ------------------------------ 6.73 KiB/10.97 KiB
# fasteners  ------------------------------ 10.77 KiB/18.24 KiB
# pydot      ------------------------------ 14.80 KiB/21.36 KiB
# orjson     ------------------------------ 62.95 KiB/138.57 KiB
# redis      ------------------------------ 64.00 KiB/249.62 KiB
# dnspython  ------------------------------ 6.73 KiB/300.48 KiB
# js2py      ------------------------------ 48.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 16.00 KiB/1.34 MiB
# fastavro   ------------------------------ 16.00 KiB/2.93 MiB
# zstandard  ------------------------------ 77.86 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠙ Preparing packages... (0/16)
# objsize    ------------------------------ 10.77 KiB/10.97 KiB
# fasteners  ------------------------------ 14.80 KiB/18.24 KiB
# orjson     ------------------------------ 94.95 KiB/138.57 KiB
# redis      ------------------------------ 64.00 KiB/249.62 KiB
# dnspython  ------------------------------ 6.73 KiB/300.48 KiB
# js2py      ------------------------------ 48.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 32.00 KiB/1.34 MiB
# fastavro   ------------------------------ 16.00 KiB/2.93 MiB
# zstandard  ------------------------------ 93.86 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠙ Preparing packages... (0/16)
# fasteners  ------------------------------ 18.24 KiB/18.24 KiB
# orjson     ------------------------------ 110.95 KiB/138.57 KiB
# redis      ------------------------------ 64.00 KiB/249.62 KiB
# dnspython  ------------------------------ 10.77 KiB/300.48 KiB
# js2py      ------------------------------ 48.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 32.00 KiB/1.34 MiB
# fastavro   ------------------------------ 16.00 KiB/2.93 MiB
# zstandard  ------------------------------ 125.86 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠙ Preparing packages... (0/16)
# orjson     ------------------------------ 126.95 KiB/138.57 KiB
# redis      ------------------------------ 64.00 KiB/249.62 KiB
# dnspython  ------------------------------ 10.77 KiB/300.48 KiB
# js2py      ------------------------------ 48.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 32.00 KiB/1.34 MiB
# fastavro   ------------------------------ 16.00 KiB/2.93 MiB
# zstandard  ------------------------------ 125.86 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠙ Preparing packages... (0/16)
# redis      ------------------------------ 80.00 KiB/249.62 KiB
# dnspython  ------------------------------ 14.80 KiB/300.48 KiB
# js2py      ------------------------------ 48.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 32.00 KiB/1.34 MiB
# fastavro   ------------------------------ 16.00 KiB/2.93 MiB
# zstandard  ------------------------------ 141.86 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠙ Preparing packages... (0/16)
# redis      ------------------------------ 80.00 KiB/249.62 KiB
# dnspython  ------------------------------ 18.84 KiB/300.48 KiB
# js2py      ------------------------------ 48.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 32.00 KiB/1.34 MiB
# fastavro   ------------------------------ 16.00 KiB/2.93 MiB
# zstandard  ------------------------------ 141.86 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠹ Preparing packages... (4/16)
# redis      ------------------------------ 80.00 KiB/249.62 KiB
# dnspython  ------------------------------ 30.95 KiB/300.48 KiB
# js2py      ------------------------------ 48.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 48.00 KiB/1.34 MiB
# fastavro   ------------------------------ 32.00 KiB/2.93 MiB
# zstandard  ------------------------------ 221.86 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# ⠹ Preparing packages... (4/16)
# redis      ------------------------------ 128.00 KiB/249.62 KiB
# dnspython  ------------------------------ 47.10 KiB/300.48 KiB
# js2py      ------------------------------ 128.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 128.00 KiB/1.34 MiB
# fastavro   ------------------------------ 112.00 KiB/2.93 MiB
# zstandard  ------------------------------ 285.86 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠹ Preparing packages... (4/16)
# redis      ------------------------------ 176.00 KiB/249.62 KiB
# dnspython  ------------------------------ 51.14 KiB/300.48 KiB
# js2py      ------------------------------ 144.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 160.00 KiB/1.34 MiB
# fastavro   ------------------------------ 144.00 KiB/2.93 MiB
# zstandard  ------------------------------ 317.86 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠹ Preparing packages... (4/16)
# redis      ------------------------------ 192.00 KiB/249.62 KiB
# dnspython  ------------------------------ 61.83 KiB/300.48 KiB
# js2py      ------------------------------ 208.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 208.00 KiB/1.34 MiB
# fastavro   ------------------------------ 208.00 KiB/2.93 MiB
# zstandard  ------------------------------ 381.86 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠸ Preparing packages... (4/16)
# redis      ------------------------------ 224.00 KiB/249.62 KiB
# dnspython  ------------------------------ 93.83 KiB/300.48 KiB
# js2py      ------------------------------ 272.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 224.00 KiB/1.34 MiB
# fastavro   ------------------------------ 272.00 KiB/2.93 MiB
# zstandard  ------------------------------ 429.86 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠸ Preparing packages... (4/16)
# redis      ------------------------------ 240.00 KiB/249.62 KiB
# dnspython  ------------------------------ 109.83 KiB/300.48 KiB
# js2py      ------------------------------ 320.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 224.00 KiB/1.34 MiB
# fastavro   ------------------------------ 336.00 KiB/2.93 MiB
# zstandard  ------------------------------ 509.86 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠸ Preparing packages... (4/16)
# redis      ------------------------------ 249.62 KiB/249.62 KiB
# dnspython  ------------------------------ 125.83 KiB/300.48 KiB
# js2py      ------------------------------ 368.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 240.00 KiB/1.34 MiB
# fastavro   ------------------------------ 368.00 KiB/2.93 MiB
# zstandard  ------------------------------ 541.86 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠸ Preparing packages... (4/16)
# dnspython  ------------------------------ 157.83 KiB/300.48 KiB
# js2py      ------------------------------ 416.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 256.00 KiB/1.34 MiB
# fastavro   ------------------------------ 416.00 KiB/2.93 MiB
# zstandard  ------------------------------ 589.86 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠸ Preparing packages... (4/16)
# dnspython  ------------------------------ 157.83 KiB/300.48 KiB
# js2py      ------------------------------ 432.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 272.00 KiB/1.34 MiB
# fastavro   ------------------------------ 432.00 KiB/2.93 MiB
# zstandard  ------------------------------ 605.86 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠼ Preparing packages... (5/16)
# dnspython  ------------------------------ 173.83 KiB/300.48 KiB
# js2py      ------------------------------ 496.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 320.00 KiB/1.34 MiB
# fastavro   ------------------------------ 480.00 KiB/2.93 MiB
# zstandard  ------------------------------ 653.86 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠼ Preparing packages... (5/16)
# dnspython  ------------------------------ 189.83 KiB/300.48 KiB
# js2py      ------------------------------ 512.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 384.00 KiB/1.34 MiB
# fastavro   ------------------------------ 531.62 KiB/2.93 MiB
# zstandard  ------------------------------ 733.86 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠼ Preparing packages... (5/16)
# dnspython  ------------------------------ 205.83 KiB/300.48 KiB
# js2py      ------------------------------ 528.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 416.00 KiB/1.34 MiB
# fastavro   ------------------------------ 627.62 KiB/2.93 MiB
# zstandard  ------------------------------ 797.86 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠼ Preparing packages... (5/16)
# dnspython  ------------------------------ 237.83 KiB/300.48 KiB
# js2py      ------------------------------ 544.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 512.00 KiB/1.34 MiB
# fastavro   ------------------------------ 691.62 KiB/2.93 MiB
# zstandard  ------------------------------ 877.86 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠴ Preparing packages... (5/16)
# dnspython  ------------------------------ 237.83 KiB/300.48 KiB
# js2py      ------------------------------ 560.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 560.00 KiB/1.34 MiB
# fastavro   ------------------------------ 771.62 KiB/2.93 MiB
# zstandard  ------------------------------ 949.86 KiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠴ Preparing packages... (5/16)
# dnspython  ------------------------------ 269.83 KiB/300.48 KiB
# js2py      ------------------------------ 587.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 651.00 KiB/1.34 MiB
# fastavro   ------------------------------ 883.62 KiB/2.93 MiB
# zstandard  ------------------------------ 1.03 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠴ Preparing packages... (5/16)
# dnspython  ------------------------------ 269.83 KiB/300.48 KiB
# js2py      ------------------------------ 635.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 699.00 KiB/1.34 MiB
# fastavro   ------------------------------ 947.62 KiB/2.93 MiB
# zstandard  ------------------------------ 1.09 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠴ Preparing packages... (5/16)
# dnspython  ------------------------------ 285.83 KiB/300.48 KiB
# js2py      ------------------------------ 683.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 731.00 KiB/1.34 MiB
# fastavro   ------------------------------ 979.62 KiB/2.93 MiB
# zstandard  ------------------------------ 1.12 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠦ Preparing packages... (5/16)
# dnspython  ------------------------------ 285.83 KiB/300.48 KiB
# js2py      ------------------------------ 683.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 731.00 KiB/1.34 MiB
# fastavro   ------------------------------ 979.62 KiB/2.93 MiB
# zstandard  ------------------------------ 1.12 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠦ Preparing packages... (5/16)
# dnspython  ------------------------------ 285.83 KiB/300.48 KiB
# js2py      ------------------------------ 699.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 747.00 KiB/1.34 MiB
# fastavro   ------------------------------ 995.62 KiB/2.93 MiB
# zstandard  ------------------------------ 1.14 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠦ Preparing packages... (5/16)
# dnspython  ------------------------------ 285.83 KiB/300.48 KiB
# js2py      ------------------------------ 747.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 795.00 KiB/1.34 MiB
# fastavro   ------------------------------ 1.00 MiB/2.93 MiB
# zstandard  ------------------------------ 1.18 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠦ Preparing packages... (5/16)
# js2py      ------------------------------ 763.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 820.81 KiB/1.34 MiB
# fastavro   ------------------------------ 1.03 MiB/2.93 MiB
# zstandard  ------------------------------ 1.21 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠦ Preparing packages... (5/16)
# js2py      ------------------------------ 795.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 852.81 KiB/1.34 MiB
# fastavro   ------------------------------ 1.03 MiB/2.93 MiB
# zstandard  ------------------------------ 1.25 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠦ Preparing packages... (5/16)
# js2py      ------------------------------ 843.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 900.81 KiB/1.34 MiB
# fastavro   ------------------------------ 1.10 MiB/2.93 MiB
# zstandard  ------------------------------ 1.29 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠧ Preparing packages... (6/16)
# js2py      ------------------------------ 907.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 932.81 KiB/1.34 MiB
# fastavro   ------------------------------ 1.14 MiB/2.93 MiB
# zstandard  ------------------------------ 1.33 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠧ Preparing packages... (6/16)
# js2py      ------------------------------ 987.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 1012.81 KiB/1.34 MiB
# fastavro   ------------------------------ 1.22 MiB/2.93 MiB
# zstandard  ------------------------------ 1.41 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠧ Preparing packages... (6/16)
# js2py      ------------------------------ 1003.00 KiB/1008.80 KiB
# pymongo    ------------------------------ 1.05 MiB/1.34 MiB
# fastavro   ------------------------------ 1.28 MiB/2.93 MiB
# zstandard  ------------------------------ 1.48 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠧ Preparing packages... (6/16)
# pymongo    ------------------------------ 1.07 MiB/1.34 MiB
# fastavro   ------------------------------ 1.29 MiB/2.93 MiB
# zstandard  ------------------------------ 1.48 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠧ Preparing packages... (6/16)
# pymongo    ------------------------------ 1.11 MiB/1.34 MiB
# fastavro   ------------------------------ 1.33 MiB/2.93 MiB
# zstandard  ------------------------------ 1.55 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠇ Preparing packages... (7/16)
# pymongo    ------------------------------ 1.19 MiB/1.34 MiB
# fastavro   ------------------------------ 1.40 MiB/2.93 MiB
# zstandard  ------------------------------ 1.61 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠇ Preparing packages... (7/16)
# pymongo    ------------------------------ 1.24 MiB/1.34 MiB
# fastavro   ------------------------------ 1.44 MiB/2.93 MiB
# zstandard  ------------------------------ 1.67 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠇ Preparing packages... (7/16)
# pymongo    ------------------------------ 1.28 MiB/1.34 MiB
# fastavro   ------------------------------ 1.55 MiB/2.93 MiB
# zstandard  ------------------------------ 1.77 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠇ Preparing packages... (7/16)
# pymongo    ------------------------------ 1.33 MiB/1.34 MiB
# fastavro   ------------------------------ 1.62 MiB/2.93 MiB
# zstandard  ------------------------------ 1.84 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠋ Preparing packages... (7/16)
# fastavro   ------------------------------ 1.65 MiB/2.93 MiB
# zstandard  ------------------------------ 1.87 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠋ Preparing packages... (7/16)
# fastavro   ------------------------------ 1.69 MiB/2.93 MiB
# zstandard  ------------------------------ 1.91 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠋ Preparing packages... (7/16)
# fastavro   ------------------------------ 1.78 MiB/2.93 MiB
# zstandard  ------------------------------ 2.00 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠋ Preparing packages... (7/16)
# fastavro   ------------------------------ 1.87 MiB/2.93 MiB
# zstandard  ------------------------------ 2.08 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠋ Preparing packages... (7/16)
# fastavro   ------------------------------ 1.95 MiB/2.93 MiB
# zstandard  ------------------------------ 2.16 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠙ Preparing packages... (8/16)
# fastavro   ------------------------------ 2.00 MiB/2.93 MiB
# zstandard  ------------------------------ 2.27 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠙ Preparing packages... (8/16)
# fastavro   ------------------------------ 2.11 MiB/2.93 MiB
# zstandard  ------------------------------ 2.39 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠙ Preparing packages... (8/16)
# fastavro   ------------------------------ 2.20 MiB/2.93 MiB
# zstandard  ------------------------------ 2.48 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠙ Preparing packages... (8/16)
# fastavro   ------------------------------ 2.31 MiB/2.93 MiB
# zstandard  ------------------------------ 2.58 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠹ Preparing packages... (8/16)
# fastavro   ------------------------------ 2.39 MiB/2.93 MiB
# zstandard  ------------------------------ 2.66 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠹ Preparing packages... (8/16)
# fastavro   ------------------------------ 2.48 MiB/2.93 MiB
# zstandard  ------------------------------ 2.73 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠹ Preparing packages... (8/16)
# fastavro   ------------------------------ 2.48 MiB/2.93 MiB
# zstandard  ------------------------------ 2.75 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠹ Preparing packages... (8/16)
# fastavro   ------------------------------ 2.59 MiB/2.93 MiB
# zstandard  ------------------------------ 2.86 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠸ Preparing packages... (8/16)
# fastavro   ------------------------------ 2.74 MiB/2.93 MiB
# zstandard  ------------------------------ 3.00 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠸ Preparing packages... (8/16)
# fastavro   ------------------------------ 2.90 MiB/2.93 MiB
# zstandard  ------------------------------ 3.16 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠸ Preparing packages... (8/16)
# fastavro   ------------------------------ 2.93 MiB/2.93 MiB
# zstandard  ------------------------------ 3.24 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠸ Preparing packages... (8/16)
# zstandard  ------------------------------ 3.30 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠸ Preparing packages... (8/16)
# zstandard  ------------------------------ 3.38 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠼ Preparing packages... (9/16)
# zstandard  ------------------------------ 3.70 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠼ Preparing packages... (9/16)
# zstandard  ------------------------------ 3.92 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠼ Preparing packages... (9/16)
# zstandard  ------------------------------ 4.07 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠼ Preparing packages... (9/16)
# zstandard  ------------------------------ 4.31 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠴ Preparing packages... (9/16)
# zstandard  ------------------------------ 4.47 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠴ Preparing packages... (9/16)
# zstandard  ------------------------------ 4.64 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠴ Preparing packages... (9/16)
# zstandard  ------------------------------ 4.73 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠴ Preparing packages... (9/16)
# zstandard  ------------------------------ 4.93 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠦ Preparing packages... (9/16)
# zstandard  ------------------------------ 5.13 MiB/5.19 MiB
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠦ Preparing packages... (9/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠦ Preparing packages... (9/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠦ Preparing packages... (9/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠦ Preparing packages... (9/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠧ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠧ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠧ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠧ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠇ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠇ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠇ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠇ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠋ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠋ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠋ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠋ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠙ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠙ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠙ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠙ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠹ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠹ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠹ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠹ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠸ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠸ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠸ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠸ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠼ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠼ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠼ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠼ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠴ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠴ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠴ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠴ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠦ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠦ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠦ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠦ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠧ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠧ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠧ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠧ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠇ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠇ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠇ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠇ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# ⠋ Preparing packages... (10/16)
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# Building crcmod==1.7
# Building dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# Building crcmod==1.7
#    Built dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# Building crcmod==1.7
#    Built dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# Building crcmod==1.7
#    Built dill==0.3.1.1
# Building hdfs==2.7.3
# Building docopt==0.6.2
# Building pyjsparser==2.7.1
# Building crcmod==1.7
#    Built dill==0.3.1.1
# Building hdfs==2.7.3
#    Built docopt==0.6.2
# Building pyjsparser==2.7.1
# Building crcmod==1.7
#    Built dill==0.3.1.1
# Building hdfs==2.7.3
#    Built docopt==0.6.2
#    Built pyjsparser==2.7.1
# Building crcmod==1.7
#    Built dill==0.3.1.1
# Building hdfs==2.7.3
#    Built docopt==0.6.2
#    Built pyjsparser==2.7.1
# Building crcmod==1.7
#    Built dill==0.3.1.1
# Building hdfs==2.7.3
#    Built docopt==0.6.2
#    Built pyjsparser==2.7.1
# Building crcmod==1.7
#    Built dill==0.3.1.1
#    Built hdfs==2.7.3
#    Built docopt==0.6.2
#    Built pyjsparser==2.7.1
# Building crcmod==1.7
#    Built dill==0.3.1.1
#    Built hdfs==2.7.3
#    Built docopt==0.6.2
#    Built pyjsparser==2.7.1
# Building crcmod==1.7
#    Built dill==0.3.1.1
#    Built hdfs==2.7.3
#    Built docopt==0.6.2
#    Built pyjsparser==2.7.1
#    Built crcmod==1.7
#    Built dill==0.3.1.1
#    Built hdfs==2.7.3
#    Built docopt==0.6.2
#    Built pyjsparser==2.7.1
#    Built dill==0.3.1.1
#    Built hdfs==2.7.3
#    Built docopt==0.6.2
#    Built pyjsparser==2.7.1
# Prepared 16 packages in 9.31s
# Uninstalled 1 package in 2ms
# Installed 16 packages in 109ms
#  + apache-beam==2.59.0
#  + crcmod==1.7
#  + dill==0.3.1.1
#  + dnspython==2.6.1
#  + docopt==0.6.2
#  + fastavro==1.9.7
#  + fasteners==0.19
#  + hdfs==2.7.3
#  + js2py==0.74
#  + objsize==0.7.0
#  + orjson==3.10.7
#  - pydot==3.0.1
#  + pydot==1.4.2
#  + pyjsparser==2.7.1
#  + pymongo==4.9.1
#  + redis==5.0.8
#  + zstandard==0.23.0

# %%
# %%writefile random-string-source.py

import time
import random
import sys

# List of random strings to print
strings = ["Hello, World!", "Apache Beam is awesome!", "Data Science rocks!",
           "Python is fun!", "Keep streaming!", "Machine Learning!",
           "Random string!", "Let's keep coding!", "Hello from the console!",
           "Keep learning!"]

# Function to print random strings for 9 seconds
def print_random_strings(duration=9):
    start_time = time.time()

    # Continue printing until the duration is met
    while time.time() - start_time < duration:
        # Select a random string from the list
        random_string = random.choice(strings)

        # Print the string to stdout
        print(random_string)

        # Flush the output to ensure immediate printing
        sys.stdout.flush()

        # Add a short delay (e.g., 0.5 seconds) between prints
        time.sleep(0.0001)

if __name__ == '__main__':
    print_random_strings()
# Out:
# Writing random-string-source.py

# %%
# !python3 random-string-source.py > lines.txt

# !cat lines.txt >> long_lines.txt
# !cat lines.txt >> long_lines.txt
# !cat lines.txt >> long_lines.txt
# !cat lines.txt >> long_lines.txt
# !cat lines.txt >> long_lines.txt
# !cat lines.txt >> long_lines.txt
# !cat lines.txt >> long_lines.txt
# !cat lines.txt >> long_lines.txt
# !cat lines.txt >> long_lines.txt
# !cat lines.txt >> long_lines.txt

# %% [markdown]
# **Pipeline IO**
#
# Example of reading contents of a file from disk and writing outputs to a file on disk.

# %%
# %%writefile beam-batching-from-file.py

import apache_beam as beam
from apache_beam import DoFn, PTransform, Pipeline
from apache_beam.io import iobase
import time
import random
import datetime
import sys

def my_sum(*args):
  return sum(*args)

def add_random_int(element):
   return (element, random.randint(1, 100))

def run():
    pipeline_options = beam.options.pipeline_options.PipelineOptions()

    with beam.Pipeline(options=pipeline_options) as p:
        # Use the custom connector to read data into the pipeline
        counts = (p
         | "Start" >> beam.io.ReadFromText("long_lines.txt")  # Create a dummy element to kickstart the stream
         | "Add Random Int" >> beam.Map(add_random_int)
         | "Group By Key" >> beam.CombinePerKey(my_sum))

        (counts
         | "Print Data" >> beam.Map(print))

        (counts
         | "Write Results To File" >> beam.io.WriteToText("results", file_name_suffix=".txt"))

if __name__ == '__main__':
    run()
# Out:
# Writing beam-batching-from-file.py

# %%
# !python3 beam-batching-from-file.py
# Out:
# ('Random string!', 2142944)
# ('Keep learning!', 2082164)
# ('Hello, World!', 2148437)
# ('Keep streaming!', 2095592)
# ('Apache Beam is awesome!', 2131295)
# ("Let's keep coding!", 2107088)
# ('Hello from the console!', 2093982)
# ('Data Science rocks!', 2076476)
# ('Python is fun!', 2093643)
# ('Machine Learning!', 2153147)

# %%
# !cat results-00000-of-00001.txt
# Out:
# ('Random string!', 2142944)
# ('Keep learning!', 2082164)
# ('Hello, World!', 2148437)
# ('Keep streaming!', 2095592)
# ('Apache Beam is awesome!', 2131295)
# ("Let's keep coding!", 2107088)
# ('Hello from the console!', 2093982)
# ('Data Science rocks!', 2076476)
# ('Python is fun!', 2093643)
# ('Machine Learning!', 2153147)

# %% [markdown]
# **Streaming, ParDo, Triggers, and Windowing**
#
# Example of streaming data (from stdin in this case using the above random-string-source.py), and applying techniques like Windowing/Triggering. Also an example of ParDo.

# %%
# %%writefile beam-streaming-from-stdin.py

import apache_beam as beam
from apache_beam import DoFn, PTransform, Pipeline
from apache_beam.io import iobase
from apache_beam.transforms.window import FixedWindows, TimestampedValue
import time
import random
import datetime
import sys

class GenerateStreamingData(DoFn):
    def process(self, element, timestamp=beam.DoFn.TimestampParam):
        # Simulate a streaming source by generating random numbers
        while True:
            now = datetime.datetime.now()
            line = sys.stdin.readline().strip()
            if not line:
                break
            yield TimestampedValue((line, random.randint(1, 100)), time.time())

class MyStreamingSource(PTransform):
    def expand(self, pcoll):
        # Apply a DoFn transform that streams data
        return pcoll | beam.ParDo(GenerateStreamingData())

def my_sum(*args):
  # print(args)
  return sum(*args)

def run():
    pipeline_options = beam.options.pipeline_options.PipelineOptions()
    pipeline_options.view_as(beam.options.pipeline_options.StandardOptions).streaming = True

    with beam.Pipeline(options=pipeline_options) as p:
        # Use the custom connector to read data into the pipeline
        (p
         | "Start" >> beam.Create([None])  # Create a dummy element to kickstart the stream
         | "Stream Data" >> MyStreamingSource()  # Use the custom streaming connector
         | "Apply Fixed Window" >> beam.WindowInto(
            FixedWindows(2),
            trigger=beam.transforms.trigger.Repeatedly(
                # beam.transforms.trigger.AfterProcessingTime(1),
                beam.transforms.trigger.AfterAny(
                  beam.transforms.trigger.AfterCount(5),
                  beam.transforms.trigger.AfterWatermark()),
                ),
            accumulation_mode=beam.transforms.trigger.AccumulationMode.DISCARDING
          ) \
         | "Group By Key" >> beam.CombinePerKey(my_sum) \
         | "Print Data" >> beam.Map(print))

if __name__ == '__main__':
    run()
# Out:
# Overwriting beam-streaming-from-stdin.py

# %%
# !python3 random-string-source.py | python3 beam-streaming-from-stdin.py
# Out:
# ('Keep streaming!', 50529)
# ('Keep streaming!', 47961)
# ('Keep streaming!', 52676)
# ('Keep streaming!', 51043)
# ('Keep streaming!', 0)
# ('Keep streaming!', 0)
# ('Keep streaming!', 0)
# ('Keep streaming!', 0)
# ('Machine Learning!', 47381)
# ('Machine Learning!', 53096)
# ('Machine Learning!', 49892)
# ('Machine Learning!', 50237)
# ('Machine Learning!', 0)
# ('Machine Learning!', 0)
# ('Machine Learning!', 0)
# ('Machine Learning!', 0)
# ('Keep learning!', 46242)
# ('Keep learning!', 52855)
# ('Keep learning!', 52091)
# ('Keep learning!', 52062)
# ('Keep learning!', 0)
# ('Keep learning!', 0)
# ('Keep learning!', 0)
# ('Keep learning!', 0)
# ('Python is fun!', 48348)
# ('Python is fun!', 53153)
# ('Python is fun!', 49419)
# ('Python is fun!', 50698)
# ('Python is fun!', 0)
# ('Python is fun!', 0)
# ('Python is fun!', 0)
# ('Python is fun!', 0)
# ('Apache Beam is awesome!', 43931)
# ('Apache Beam is awesome!', 53218)
# ('Apache Beam is awesome!', 51499)
# ('Apache Beam is awesome!', 52302)
# ('Apache Beam is awesome!', 0)
# ('Apache Beam is awesome!', 0)
# ('Apache Beam is awesome!', 0)
# ('Apache Beam is awesome!', 0)
# ('Hello, World!', 43742)
# ('Hello, World!', 53589)
# ('Hello, World!', 54682)
# ('Hello, World!', 45548)
# ('Hello, World!', 0)
# ('Hello, World!', 0)
# ('Hello, World!', 0)
# ('Hello, World!', 0)
# ('Data Science rocks!', 47820)
# ('Data Science rocks!', 55273)
# ('Data Science rocks!', 53792)
# ('Data Science rocks!', 52456)
# ('Data Science rocks!', 0)
# ('Data Science rocks!', 0)
# ('Data Science rocks!', 0)
# ('Data Science rocks!', 0)
# ("Let's keep coding!", 44920)
# ("Let's keep coding!", 53383)
# ("Let's keep coding!", 50538)
# ("Let's keep coding!", 49765)
# ("Let's keep coding!", 0)
# ("Let's keep coding!", 0)
# ("Let's keep coding!", 0)
# ("Let's keep coding!", 0)
# ('Hello from the console!', 43615)
# ('Hello from the console!', 52822)
# ('Hello from the console!', 49485)
# ('Hello from the console!', 49597)
# ('Hello from the console!', 0)
# ('Hello from the console!', 0)
# ('Hello from the console!', 0)
# ('Hello from the console!', 0)
# ('Random string!', 44990)
# ('Random string!', 53578)
# ('Random string!', 49949)
# ('Random string!', 50155)
# ('Random string!', 0)
# ('Random string!', 0)
# ('Random string!', 0)
# ('Random string!', 0)

# %%
# !wget https://file-examples.com/storage/fe3ab4a58d66f32059e89a1/2017/04/file_example_MP4_480_1_5MG.mp4
# Out:
# --2024-09-24 21:17:53--  https://file-examples.com/storage/fe3ab4a58d66f32059e89a1/2017/04/file_example_MP4_480_1_5MG.mp4
# Resolving file-examples.com (file-examples.com)... 185.135.88.81
# Connecting to file-examples.com (file-examples.com)|185.135.88.81|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1570024 (1.5M) [video/mp4]
# Saving to: ‘file_example_MP4_480_1_5MG.mp4’
#
# file_example_MP4_48 100%[===================>]   1.50M  2.39MB/s    in 0.6s
#
# 2024-09-24 21:17:54 (2.39 MB/s) - ‘file_example_MP4_480_1_5MG.mp4’ saved [1570024/1570024]

# %% [markdown]
# **Composite Transforms**
#
# Example of streaming a video into frames (i.e. images) and processing them in a composite transform. Then splitting the pipeline into two to process the frames further.

# %%
import apache_beam as beam
from apache_beam.options.pipeline_options import PipelineOptions
import cv2

class StreamVideoFrames(beam.DoFn):
    def __init__(self, source):
        self.source = source

    def setup(self):
        # Open the video source only once
        self.cap = cv2.VideoCapture(self.source)

    def process(self, element, timestamp=beam.DoFn.TimestampParam):
        """Process video frames from the source."""
        while self.cap.isOpened():
            ret, frame = self.cap.read()
            if not ret:
                break
            # You can assign a timestamp or just yield the frame
            yield frame

    def teardown(self):
        # Release the video source when done
        self.cap.release()

class GrayscaleAndHashTransform(beam.PTransform):
    def expand(self, pcoll):
        return (pcoll
         | "Grayscale Frame" >> beam.Map(lambda frame: cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY))
         | "Draw Bounding Box" >> beam.Map(lambda frame: cv2.rectangle(frame, (50, 50), (200, 200), (25, 0, 180), 2))
         | "Add Image Hash" >> beam.Map(lambda frame: (frame, cv2.img_hash.pHash(frame))))

def run_pipeline(source=0):
    options = PipelineOptions(streaming=True)
    with beam.Pipeline(options=options) as p:
        frames = (p
         | "Start" >> beam.Create([None])  # Start the pipeline with an initial dummy element
         | "Stream Video Frames" >> beam.ParDo(StreamVideoFrames(source='file_example_MP4_480_1_5MG.mp4'))
        )

        shapes = (frames
         | "Grayscale and Hash" >> GrayscaleAndHashTransform()
         | "Print Frame Shape" >> beam.Map(lambda element: print(element[0].shape))
        )

        hashes = (frames
         | "Grayscale and Hash2" >> GrayscaleAndHashTransform()
         | "Print Image Hash" >> beam.Map(lambda element: print(element[1]))
        )

if __name__ == '__main__':
    run_pipeline()
# Out:
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-ee4373d8-7e3a-4ac8-a461-a9e8c5dd3474.json']
# (270, 480)
# [[243 187  60 204 142 227 252  51]]
# (270, 480)
# [[243 187  60 204 142 227 252  51]]
# (270, 480)
# [[243 187  60 204 142 227 252  51]]
# (270, 480)
# [[243 255  60 204 142 227 252  51]]
# (270, 480)
# [[243 255  60 204 142 243 236  51]]
# (270, 480)
# [[243 251  60 204 142 243 252  51]]
# (270, 480)
# [[243 251  60 204 142 243 252  51]]
# (270, 480)
# [[243 255  60 204 142 227 252  51]]
# (270, 480)
# [[243 255  60 204 142 227 252  51]]
# (270, 480)
# [[243 251  60 204 142 243 252  51]]
# (270, 480)
# [[243 187  60 204 142 243 252  51]]
# (270, 480)
# [[243 187  60 204 142 243 252  51]]
# (270, 480)
# [[243 187  60 204 142 243 252 115]]
# (270, 480)
# [[243 187  60 204 142 243 252  51]]
# (270, 480)
# [[243 187  60 204 142 243 252  51]]
# (270, 480)
# [[243 187  60 204 142 251 252  51]]
# (270, 480)
# [[243 187  60 204 142 251 252  51]]
# (270, 480)
# [[243 187  60 204 142 243 252  51]]
# (270, 480)
# [[243 187  60 204 142 243 252  51]]
# (270, 480)
# [[243 187  60 204 142 115 252  51]]
# (270, 480)
# [[243 187  60 204 142  99 252  51]]
# (270, 480)
# [[243 187  60 204 142  99 252  51]]
# (270, 480)
# [[243 187  60 204 142  99 252  51]]
# (270, 480)
# [[243 187  60 204 142  99 252  51]]
# (270, 480)
# [[243 187  60 204 142  99 252  51]]
# (270, 480)
# [[243 187  60 204 142  99 252  51]]
# (270, 480)
# [[243 187  60 204 142  99 252  51]]
# (270, 480)
# [[243 191  60 204 142  99 252  51]]
# (270, 480)
# [[243 187  60 204 142  99 252  51]]
# (270, 480)
# [[243 187  60 204 142 115 252  51]]
# (270, 480)
# [[243 187  60 204 142 115 252  51]]
# (270, 480)
# [[243 153  60 206 142 243 252  51]]
# (270, 480)
# [[243 153  60 206 142 115 252  51]]
# (270, 480)
# [[243 153  60 206 142 115 252  51]]
# (270, 480)
# [[227 153  60 206 142 115 252  51]]
# (270, 480)
# [[227 153  60 206 142  99 252  51]]
# (270, 480)
# [[243 153  60 206 142  99 252 179]]
# (270, 480)
# [[243 153  60 206 142  99 252  51]]
# (270, 480)
# [[243 153  60 206 142  99 252  51]]
# (270, 480)
# [[243 155  60 204 142  99 252  51]]
# (270, 480)
# [[243 153  60 206 142  99 252  51]]
# (270, 480)
# [[243 153  60 206 142 115 252  51]]
# (270, 480)
# [[243 153  60 206 142 115 124  51]]
# (270, 480)
# [[243 155  60 204 142 115 124  51]]
# (270, 480)
# [[243 187  60 204 142 115 124 179]]
# (270, 480)
# [[243 187  60 204 142 115 124 179]]
# (270, 480)
# [[243 187  60 204 142 115 124 179]]
# (270, 480)
# [[243 187  60 204 142  99 124 179]]
# (270, 480)
# [[227 187  60 204 142  99 124 179]]
# (270, 480)
# [[227 155  60 204 142  99 124 179]]
# (270, 480)
# [[227 187  60 204 142  99 252 187]]
# (270, 480)
# [[227 187  60 204 142  99 252 179]]
# (270, 480)
# [[227 155  60 206 142  99 252 179]]
# (270, 480)
# [[227 153  60 206 142 115 252 179]]
# (270, 480)
# [[227 153  60 206 142 115 252  51]]
# (270, 480)
# [[243 153  60 206 142 115 124  51]]
# (270, 480)
# [[243 153  60 206 142  99 124  51]]
# (270, 480)
# [[243 153  60 206 142  99 252  59]]
# (270, 480)
# [[243 153  60 206 142 115 252  59]]
# (270, 480)
# [[243 153  60 206 142 115 252 123]]
# (270, 480)
# [[227 153  60 206 142 115 124  59]]
# (270, 480)
# [[227 153  60 206 142 115 124 187]]
# (270, 480)
# [[227 153  60 206 142 115 124 251]]
# (270, 480)
# [[227 153  60 206 142 115 124 251]]
# (270, 480)
# [[227 153  60 206 142 115 124 251]]
# (270, 480)
# [[227 153  60 206 142 115 124 187]]
# (270, 480)
# [[227 153  60 206 142 115 124 187]]
# (270, 480)
# [[227 153  60 206 142 115 124 187]]
# (270, 480)
# [[227 153  60 206 142 115 124  59]]
# (270, 480)
# [[227 153  60 206 142 115 124  51]]
# (270, 480)
# [[227 153  60 206 142 115 124 187]]
# (270, 480)
# [[227 153  60 206 142 115 124 187]]
# (270, 480)
# [[227 153  60 206 142 115 124 187]]
# (270, 480)
# [[227 153  60 206 142 115 124 179]]
# (270, 480)
# [[227 153  60 206 142 115 124 179]]
# (270, 480)
# [[227 153  60 206 142 115 124 187]]
# (270, 480)
# [[227 153  60 206 142 115 124 187]]
# (270, 480)
# [[243 153  60 206 142 115 124 187]]
# (270, 480)
# [[243 153  60 206 142 115 124  59]]
# (270, 480)
# [[243 153  60 206 142 115 124  59]]
# (270, 480)
# [[243 153  60 206 142 115 124  59]]
# (270, 480)
# [[243 153  60 206 142 115  60  59]]
# (270, 480)
# [[243 153  60 206 142 115  60  59]]
# (270, 480)
# [[227 153  60 230 142 115 124  59]]
# (270, 480)
# [[227 153  60 230 142 243 124  59]]
# (270, 480)
# [[227 153  60 230 142 243 124  59]]
# (270, 480)
# [[227 153  60 206 142 115  60  59]]
# (270, 480)
# [[227 153  60 206 142 115  60  59]]
# (270, 480)
# [[227 153  60 206 142 115  60  59]]
# (270, 480)
# [[243 153  60 206 142 115  60 123]]
# (270, 480)
# [[243 153  60 206 142 115 124 123]]
# (270, 480)
# [[243 153  60 206 142 115 124 123]]
# (270, 480)
# [[227 153  60 206 142 115 124 121]]
# (270, 480)
# [[227 153  60 206 142 115 124  89]]
# (270, 480)
# [[243 153  60 206 142 115  92  89]]
# (270, 480)
# [[243 153  60 230 142 115 124 121]]
# (270, 480)
# [[243 153  60 230 142 115 124 121]]
# (270, 480)
# [[243 153  60 198 142 115 124 123]]
# (270, 480)
# [[243 153  60 206 142 115  60 123]]
# (270, 480)
# [[243 217  60 206 142 243  60 123]]
# (270, 480)
# [[227 217  60 230 142 243  60 123]]
# (270, 480)
# [[227 153  60 230 142 243 252 115]]
# (270, 480)
# [[243 153  60 230 142 251 124 115]]
# (270, 480)
# [[243 153  60 230 142 251  60 115]]
# (270, 480)
# [[243 153  60 230 142 251  60 115]]
# (270, 480)
# [[227 153  60 230 142 251  60 115]]
# (270, 480)
# [[227 217  60 230 142 123  60  51]]
# (270, 480)
# [[227 217  60 230 142 115 124  51]]
# (270, 480)
# [[227 217  60 198 142 115 124  59]]
# (270, 480)
# [[227 217  60 198 142 115 124  59]]
# (270, 480)
# [[227 153  60 206 142 115 252  59]]
# (270, 480)
# [[243 153  60 206 142 115 252  59]]
# (270, 480)
# [[243 153  60 206 142 115 188 123]]
# (270, 480)
# [[243 153  60 198 142 115 188 123]]
# (270, 480)
# [[243 153  60 230 142 115 188 115]]
# (270, 480)
# [[243 153  60 230 142 115 188 115]]
# (270, 480)
# [[243 153  60 230 142 115 156 123]]
# (270, 480)
# [[243 153  60 230 142 115 156 123]]
# (270, 480)
# [[243 153  60 230 142 115 156 123]]
# (270, 480)
# [[243 153  60 230 142 115 156 123]]
# (270, 480)
# [[243 153  60 230 142 115 188 123]]
# (270, 480)
# [[243 153  60 230 142 115 188 123]]
# (270, 480)
# [[243 153  60 230 142 115 188  59]]
# (270, 480)
# [[243 153  60 230 142 243 188 123]]
# (270, 480)
# [[243 153  60 230 142 243 156 123]]
# (270, 480)
# [[243 153  60 230 142 243 156 123]]
# (270, 480)
# [[227 153  60 230 142 243 156 123]]
# (270, 480)
# [[243 153  60 230 142 243 156 123]]
# (270, 480)
# [[243 153  60 230 142 243 156 123]]
# (270, 480)
# [[243 153  60 230 142 243 156 123]]
# (270, 480)
# [[243 153  60 230 142 243 156 121]]
# (270, 480)
# [[243 153  60 230 142 243 156 121]]
# (270, 480)
# [[243 153  60 230 142 243 220 121]]
# (270, 480)
# [[243 153  60 230 142 243 220 121]]
# (270, 480)
# [[243 153  60 230 142 243 220 123]]
# (270, 480)
# [[243 153  60 230 142 243 220 123]]
# (270, 480)
# [[243 153  60 230 142 243 220 123]]
# (270, 480)
# [[243 153  60 230 142 243 220 123]]
# (270, 480)
# [[243 153  60 230 142 243 220 123]]
# (270, 480)
# [[243 153  60 230 142 243 156 123]]
# (270, 480)
# [[243 153  60 230 142 243 156 123]]
# (270, 480)
# [[243 153  60 230 142 243 156 123]]
# (270, 480)
# [[243 153  60 230 142 243 156  59]]
# (270, 480)
# [[243 153  60 230 142 243 156  59]]
# (270, 480)
# [[243 153  60 230 142 243 156  59]]
# (270, 480)
# [[243 217  60 230 142 243 220  59]]
# (270, 480)
# [[243 217  60 230 142 235 220  59]]
# (270, 480)
# [[243 217  60 230 142 251 220 123]]
# (270, 480)
# [[243 217  60 230 142 251 220 123]]
# (270, 480)
# [[243 217  60 230 142 227 220 123]]
# (270, 480)
# [[243 217  60 230 142 227 220 123]]
# (270, 480)
# [[243 217  60 230 142 243 220 123]]
# (270, 480)
# [[243 217  60 230 142 243 220 123]]
# (270, 480)
# [[243 217  60 230 142 243 220 123]]
# (270, 480)
# [[243 217  60 230 142 243 220 123]]
# (270, 480)
# [[243 217  60 230 142 251 220 123]]
# (270, 480)
# [[243 217  60 230 142 251 220 119]]
# (270, 480)
# [[243 217  60 230 142 251 220 119]]
# (270, 480)
# [[243 217  60 230 142 243 220 119]]
# (270, 480)
# [[243 217  60 230 142 243 220 115]]
# (270, 480)
# [[243 217  60 230 142 243 220 123]]
# (270, 480)
# [[243 217  60 230 142 243 156 123]]
# (270, 480)
# [[243 217  60 230 142 243 156  51]]
# (270, 480)
# [[243 217  60 230 142 243 156  51]]
# (270, 480)
# [[243 217  60 230 142 243 156  51]]
# (270, 480)
# [[243 217  60 230 142 243 156  51]]
# (270, 480)
# [[243 217  60 230 142 243 220  51]]
# (270, 480)
# [[243 217  60 230 142 243 220  51]]
# (270, 480)
# [[243 217  60 230 142 243 220  51]]
# (270, 480)
# [[243 217  60 230 142 227 220  59]]
# (270, 480)
# [[243 217  60 230 142 227 220  59]]
# (270, 480)
# [[243 217  60 230 142 227 220  59]]
# (270, 480)
# [[243 217  60 230 142 227 220 123]]
# (270, 480)
# [[243 217  60 230 142 227 220 123]]
# (270, 480)
# [[243 217  60 230 142 227 220  59]]
# (270, 480)
# [[243 217  60 230 142 251 220 123]]
# (270, 480)
# [[243 217  60 230 142 251 220 123]]
# (270, 480)
# [[243 217  60 230 142 251 220 127]]
# (270, 480)
# [[243 217  60 230 142 251 220 119]]
# (270, 480)
# [[243 217  60 230 142 251 220 119]]
# (270, 480)
# [[243 217  60 230 142 251 220 127]]
# (270, 480)
# [[243 217  60 230 142 235 220 123]]
# (270, 480)
# [[243 217  60 230 142 235 220  59]]
# (270, 480)
# [[227 204  60 198 142  99 236  59]]
# (270, 480)
# [[227 204  60 198 142  99 236  57]]
# (270, 480)
# [[227 204  60 198 142  99 236  57]]
# (270, 480)
# [[227 140  60 230 142  99 236  57]]
# (270, 480)
# [[227 204  60 230 142  99 236  57]]
# (270, 480)
# [[227 204  60 230 142  99 108  57]]
# (270, 480)
# [[227 204  60 198 142  99 236  59]]
# (270, 480)
# [[227 204  60 198 142 103 236  59]]
# (270, 480)
# [[227 204  60 198 142 103 108 123]]
# (270, 480)
# [[227 204  60 198 142 103 108 123]]
# (270, 480)
# [[227 204  60 198 142 103 236 123]]
# (270, 480)
# [[227 204  60 198 142  99 236 123]]
# (270, 480)
# [[227 204  60 198 142  99 108 123]]
# (270, 480)
# [[227 204  60 198 142  99 108 123]]
# (270, 480)
# [[227 204  60 206 142  99 108 115]]
# (270, 480)
# [[227 204  60 206 142  99 108 115]]
# (270, 480)
# [[227 204  60 206 142  99 108 115]]
# (270, 480)
# [[227 204  60 206 142  99 108 115]]
# (270, 480)
# [[227 204  60 206 142  99 108 115]]
# (270, 480)
# [[227 204  60 206 142  99 108 115]]
# (270, 480)
# [[227 204  60 206 142  99 108 115]]
# (270, 480)
# [[227 204  60 206 142 115 108 115]]
# (270, 480)
# [[227 204  60 206 142 115 108 115]]
# (270, 480)
# [[227 204  60 206 142  99 108 115]]
# (270, 480)
# [[227 204  60 206 142  99 108 115]]
# (270, 480)
# [[227 204  60 206 142  99 108 115]]
# (270, 480)
# [[227 204  60 206 142  99 108 243]]
# (270, 480)
# [[227 204  60 206 142  99 108 243]]
# (270, 480)
# [[227 204  60 206 142  99 108 243]]
# (270, 480)
# [[227 204  60 206 142  99 108 123]]
# (270, 480)
# [[227 204  60 206 142 115 108 123]]
# (270, 480)
# [[227 204  60 206 142 115 108 123]]
# (270, 480)
# [[227 204  60 206 142 115 236 115]]
# (270, 480)
# [[227 204  60 206 142 115 236 243]]
# (270, 480)
# [[227 204  60 206 142 115 236 243]]
# (270, 480)
# [[227 204  60 206 142 115 236 243]]
# (270, 480)
# [[227 204  60 206 142 115 236 243]]
# (270, 480)
# [[227 204  60 206 142 115 108 243]]
# (270, 480)
# [[227 204  60 206 142 115 236 243]]
# (270, 480)
# [[227 204  60 206 142 115 236 243]]
# (270, 480)
# [[227 204  60 206 142 115 236 243]]
# (270, 480)
# [[227 204  60 206 142 115 236 243]]
# (270, 480)
# [[227 204  60 206 142 115 236 243]]
# (270, 480)
# [[227 204  60 206 142 115 108 243]]
# (270, 480)
# [[227 204  60 206 142 115 108 115]]
# (270, 480)
# [[227 204  60 204 142  99 108 115]]
# (270, 480)
# [[227 204  60 204 142  99 108 115]]
# (270, 480)
# [[227 204  60 204 142  99 108 123]]
# (270, 480)
# [[227 204  60 204 142  99 108 115]]
# (270, 480)
# [[227 204  60 204 142 115 108 115]]
# (270, 480)
# [[227 204  60 206 142 115 108 115]]
# (270, 480)
# [[227 204  60 206 142 115 108 115]]
# (270, 480)
# [[227 204  60 204 142 115 108 115]]
# (270, 480)
# [[227 204  60 204 142 115 108 115]]
# (270, 480)
# [[227 204  60 204 142 115 108 115]]
# (270, 480)
# [[227 204  60 206 142 115 108 115]]
# (270, 480)
# [[227 204  60 204 142 115 108 115]]
# (270, 480)
# [[227 204  60 204 142 115 108 115]]
# (270, 480)
# [[227 204  60 204 142 115 108 115]]
# (270, 480)
# [[227 204  60 204 142 115 108 115]]
# (270, 480)
# [[227 204  60 204 142 115 108 123]]
# (270, 480)
# [[227 204  60 204 142 115 108 127]]
# (270, 480)
# [[227 204  60 206 142 115 108 115]]
# (270, 480)
# [[227 204  60 206 142 115 108 115]]
# (270, 480)
# [[227 204  60 206 142 115 108 115]]
# (270, 480)
# [[227 204  60 206 142 115 108 115]]
# (270, 480)
# [[227 204  60 206 142 115 108 243]]
# (270, 480)
# [[227 204  60 206 142 115 108 251]]
# (270, 480)
# [[227 204  60 206 142 115 108 243]]
# (270, 480)
# [[227 204  60 206 142 115 108 115]]
# (270, 480)
# [[227 204  60 206 142 115 124 115]]
# (270, 480)
# [[227 204  60 204 142 115 124 115]]
# (270, 480)
# [[227 204  60 204 142 115 124 115]]
# (270, 480)
# [[227 204  60 204 142 115  60 115]]
# (270, 480)
# [[227 204  60 204 142 115  60 115]]
# (270, 480)
# [[227 204  60 204 142 115  60 115]]
# (270, 480)
# [[227 204  60 204 142 115  60 115]]
# (270, 480)
# [[227 204  60 204 142 115  60 115]]
# (270, 480)
# [[227 204  60 204 142 115  60 115]]
# (270, 480)
# [[227 204  60 204 142 115  60 115]]
# (270, 480)
# [[227 204  60 204 142 115 124 115]]
# (270, 480)
# [[227 204  60 204 142 115 108 115]]
# (270, 480)
# [[227 204  60 204 142 115 108 115]]
# (270, 480)
# [[227 204  60 204 142 115 108 115]]
# (270, 480)
# [[227 204  60 204 142 115 108 115]]
# (270, 480)
# [[227 204  60 204 142 115 108 115]]
# (270, 480)
# [[227 204  60 204 142 115 108 115]]
# (270, 480)
# [[227 204  60 204 142 115 108 115]]
# (270, 480)
# [[227 204  60 204 142 115 108 115]]
# (270, 480)
# [[227 204  60 204 142 115 124 115]]
# (270, 480)
# [[227 204  60 204 142 243 108 115]]
# (270, 480)
# [[227 204  60 204 142 243 252 115]]
# (270, 480)
# [[227 204  60 204 142 115 124 115]]
# (270, 480)
# [[227 204  60 204 142 115  60 115]]
# (270, 480)
# [[227 204  60 204 142 115  60 115]]
# (270, 480)
# [[227 206  60 204 142 115  60 115]]
# (270, 480)
# [[227 206  60 204 142 243 124 115]]
# (270, 480)
# [[227 206  60 204 142 243 124 115]]
# (270, 480)
# [[227 206  60 204 142 243 124 115]]
# (270, 480)
# [[243 255  60 204 142 115 124 115]]
# (270, 480)
# [[243 255  60 204 142 243 124 115]]
# (270, 480)
# [[243 238  60 204 142 243 124 115]]
# (270, 480)
# [[227 238  60 204 142 243 124 115]]
# (270, 480)
# [[227 206  60 204 142 243 108 115]]
# (270, 480)
# [[227 206  60 204 142 243 108 115]]
# (270, 480)
# [[227 206  60 204 142 243 236 115]]
# (270, 480)
# [[227 206  60 204 142 243 108 115]]
# (270, 480)
# [[227 206  60 204 142 243 236 115]]
# (270, 480)
# [[227 206  60 204 142 243 236 115]]
# (270, 480)
# [[227 206  60 204 142 243 108 115]]
# (270, 480)
# [[227 238  60 204 142 243 124 115]]
# (270, 480)
# [[227 238  60 204 142 243 124 115]]
# (270, 480)
# [[227 206  60 204 142 243 252 115]]
# (270, 480)
# [[227 206  60 204 142 243 188 115]]
# (270, 480)
# [[243 222  60 204 142 243 188 115]]
# (270, 480)
# [[243 254  60 204 142 243 188 115]]
# (270, 480)
# [[243 126  60 204 142 243 188 115]]
# (270, 480)
# [[243 126  60 204 142 243 188 115]]
# (270, 480)
# [[243 126  60 204 142 243 188 115]]
# (270, 480)
# [[243 126  60 204 142 243 188 115]]
# (270, 480)
# [[243 254  60 204 142 243 188  51]]
# (270, 480)
# [[243 254  60 204 142 243 188  51]]
# (270, 480)
# [[243 254  60 204 142 227 188  51]]
# (270, 480)
# [[243 254  60 204 142 227 188  51]]
# (270, 480)
# [[243 110  60 204 142 227 252  51]]
# (270, 480)
# [[243 126  60 204 142 227 252  51]]
# (270, 480)
# [[243 126  60 204 142 227 252  51]]
# (270, 480)
# [[243 110  60 204 142 227 236  51]]
# (270, 480)
# [[227 110  60 204 142 243 236 115]]
# (270, 480)
# [[243 110  60 204 142 243 236 115]]
# (270, 480)
# [[243 126  60 204 142 243 236 115]]
# (270, 480)
# [[243 110  60 204 142 243 236 115]]
# (270, 480)
# [[243 110  60 204 142 243 252 115]]
# (270, 480)
# [[243 110  60 204 142 243 252 115]]
# (270, 480)
# [[243 126  60 204 142 243 252 115]]
# (270, 480)
# [[243 126  60 204 142 243 252 115]]
# (270, 480)
# [[243  63  60 204 142 243 188 115]]
# (270, 480)
# [[243  63  60 204 142 243 188 115]]
# (270, 480)
# [[243  63  60 204 142 243 188 115]]
# (270, 480)
# [[243 191  60 206 142 243 156  51]]
# (270, 480)
# [[243 191  60 204 142 243 156  51]]
# (270, 480)
# [[243  63  60 204 142 243 156  51]]
# (270, 480)
# [[243  62  60 204 142 243 156  51]]
# (270, 480)
# [[243  62  60 204 142 243 188  51]]
# (270, 480)
# [[243  62  60 204 142 243 220  51]]
# (270, 480)
# [[243  63  60 204 142 243 220  51]]
# (270, 480)
# [[243  63  60 204 142 243 252  51]]
# (270, 480)
# [[243  63  60 204 142 243 252  51]]
# (270, 480)
# [[243  63  60 204 142 243 252  51]]
# (270, 480)
# [[243  63  60 204 142 243 252  51]]
# (270, 480)
# [[243 127  60 204 142 243 252  51]]
# (270, 480)
# [[243 126  60 204 142 243 252  51]]
# (270, 480)
# [[243 126  60 204 142 243 252  51]]
# (270, 480)
# [[243 126  60 204 142 243 252  51]]
# (270, 480)
# [[243 126  60 204 142 243 252  51]]
# (270, 480)
# [[243  63  60 204 142 243 252  51]]
# (270, 480)
# [[243  63  60 204 142 243 252 115]]
# (270, 480)
# [[243  63  60 204 142 243 252 115]]
# (270, 480)
# [[243  59  60 204 142 243 252  51]]
# (270, 480)
# [[243  59  60 204 142 243 252  51]]
# (270, 480)
# [[243  59  60 204 142 243 252  51]]
# (270, 480)
# [[243  59  60 204 142 243 252  51]]
# (270, 480)
# [[243 187  60 204 142 243 252  51]]
# (270, 480)
# [[243 187  60 204 142 243 252  51]]
# (270, 480)
# [[243 187  60 204 142 243 252  51]]
